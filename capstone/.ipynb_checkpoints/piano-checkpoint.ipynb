# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import librosa
import IPython.display as ipd 
import logging

# %%
BASE_DIR = "/Users/gina0/Desktop/fourier_analysis/capstone/sound_folder"
piano_c5_file = "piano_c5.wav"

# %%
ipd.Audio(os.path.join(BASE_DIR, piano_c5_file))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
piano_c5_data, sr = librosa.load(os.path.join(BASE_DIR, piano_c5_file)) #sr = 22050

# %%
len(piano_c5_data)
# Out:
# 46206

# %%
# Plot time domain graph
time = np.arange(0, len(piano_c5_data)) / sr
plt.figure(figsize=(18,5))
plt.plot(time, piano_c5_data)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Audio Waveform (Piano C5)')
plt.show()

# %%
# apply DFT with numpy
# %%time
T = len(piano_c5_data) / sr #record length(audio time)
N = len(piano_c5_data)
freq = np.linspace(0, sr, len(piano_c5_data))
Y_n = np.zeros(len(piano_c5_data))

for p in range(0, N//4, 2):
    for n in range(0, N):
        y_j = piano_c5_data[n]
        w_j = np.exp(-1j*2*np.pi*p*n/N)
        Y_n[p] += (y_j*w_j).real

magnitude_spectrum = np.abs(Y_n)
plt.figure(figsize=(18,5))
plt.plot(freq[:len(freq)//2], magnitude_spectrum[:len(Y_n)//2])
plt.xlabel('Freq (f)')
plt.ylabel('Magnitude')
plt.title('DFT (Piano C5)')
plt.show()

# %%
# apply DFT with pandas

# %%
# apply FFT

piano_c5_fft = np.fft.fft(piano_c5_data)
ms_piano_c5_fft = np.abs(piano_c5_fft)
phase = np.angle(piano_c5_fft)

# %%
piano_c5_fft[0] #in complex number since fft is applied
ms_piano_c5_fft[0] #in real number (magnitude spectrum)

# %%
# Plot freq domain graph
freq = np.linspace(0, sr, len(ms_piano_c5_fft)) #[start, stop] num evenly spaced
plt.figure(figsize=(18,5))
plt.plot(freq, piano_c5_fft)
plt.xlabel('Freq (f)')
plt.ylabel('Magnitude')
plt.title('FFT (Piano C5)')
plt.show()
# Out:
# C:\Users\gina0\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\cbook.py:1719: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# C:\Users\gina0\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\cbook.py:1355: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
threshold = 200
ms_piano_c5_fft_filtered = np.where(ms_piano_c5_fft < threshold, 0, ms_piano_c5_fft)

# %%
plt.figure(figsize=(18,5))
plt.plot(freq, ms_piano_c5_fft_filtered)
plt.xlabel('Freq (f)')
plt.ylabel('Magnitude')
plt.title('FFT (Piano C5)')
plt.show()

# %%
# Inverst FFT from freq to time domain
piano_c5_data_filtered = np.fft.ifft(ms_piano_c5_fft_filtered)
plt.plot(time, piano_c5_data_filtered)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Audio Waveform (Piano C5)')
plt.show()
